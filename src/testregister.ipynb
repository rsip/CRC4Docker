# %%
# %matplotlib inline

# %%
ls myimagery
# Out:
# 97_radianz_registriert_voll      RS2_20090712.tif        RS2_20100520.tif
# 97_radianz_registriert_voll.hdr  RS2_20090805.tif        RS2_20100707.tif
# gcps.pts                         RS2_20090829_enl.tif    RS2_20100731.tif
# LS19840717.tif                   RS2_20090829_gamma.tif  RS2_20100824.tif
# outxx_bmap                       RS2_20090829_mmse.tif   RS2_20101011.tif
# outxx_cmap                       RS2_20090829_sub.tif    sarseq_bmap.tif
# outxx_fmap                       RS2_20090829.tif        sarseq_cmap.tif
# outxx_smap                       RS2_20091016.tif        sarseq_fmap.tif
# RS2_20090525.tif                 RS2_20091016_warp.tif   sarseq_smap.tif
# RS2_20090618.tif                 RS2_20100426.tif        SRTM.tif

# %%
run scripts/sar_seq -d [100,100,400,400] myimagery/RS2_20090829.tif myimagery/RS2_20091016.tif outxx 12
# Out:
# ...
# Spatial/spectral subsetting
# ...
# Tue Jul 31 14:32:32 2018
# Input myimagery/RS2_20090829.tif
# elapsed time: 0.107870101929
#
# attempting parallel execution of co-registration ...
# Waiting for connection file: ~/.ipython/profile_default/security/ipcontroller-client.json
# Connection file '~/.ipython/profile_default/security/ipcontroller-client.json' not found.
# You have attempted to connect to an IPython Cluster but no Controller could be found.
# Please double-check your configuration and ensure that a cluster is running.
# Failed, so running sequential co-registration ...
# ...
#      Register SAR
# ...
# Tue Jul 31 14:32:42 2018
# Reference SAR image:
#  myimagery/RS2_20090829.tif
# Target SAR image:
#  myimagery/RS2_20091016.tif
# warping 9 bands (quad pol)...
# Warped image written to: /home/mort/python/CRC4Docker/src/myimagery/RS2_20091016_warp.tif
# elapsed time: 3.70948910713
# elapsed time for co-registration: 13.8357601166
# ...
#      Multi-temporal SAR Change Detection
# ...

# %%
run scripts/dispms -f myimagery/outxx_cmap -c
